# %% [markdown]
#     JECRC University                  Yash Kumar Sharma                                                            20MCIN005

# %% [markdown]
#                     Project: White Wine Data Exploratory Data Analysis (EDA)

# %% [markdown]
# ## White Wine Data
# ## Exploratory Data Analysis (EDA)
#
# The process of analyzing the data, discovering the patterns, spotting anomalies, testing hypotheses, and checking the assumption. We use summary statistics and graphical representations for the EDA.  <br><br>
#
# Project Objective
# <br><br>
# Study the data set of white wine quality. The objective of the study is to conduct EDA on several parameters of the data set.
# <br>
# Exploratory Data Analysis
# <br>
#     Understand the data using the pandas library
#
#     1.    Print the first five rows of the dataset
#     2.    Print the last five rows of the dataset
#     3.    Find out the total number of rows and columns of the data set
#     4.    Find out the columns, data types, and presence of null values or missing values in the data set
#           Univariate Analysis
#     5.    Find out missing values graphically
#     6.    Find out the number of rows, mean, std deviation, min, Q1, Q2, Q3, max values for each variable. Document your         observations to check if the outliers are present in the data set
#     7.    Draw the histogram, kernel density estimate (kde) to check the distribution and skewness for each variable. Document your observation
#     8.    Create a frequency distribution table and bar chart for the output variable
#     9.    Draw box plot for each variable and identify the IQR and outliers
#         Multivariate Analysis
#     11.   Draw the correlation matrix and identify the variables that are correlated to each other.

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt



import warnings
warnings.filterwarnings("ignore")

# %%
#import the file

imp = pd.read_csv('white.csv',sep=";")
imp
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
imp.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# ## 1. Print the first five rows of the dataset

# %%
imp.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %% [markdown]
# ## 2. Print the last five rows of the dataset

# %%
imp.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6

# %% [markdown]
# ## 3.Find out the total number of rows and columns of the data set

# %%
print("Number of rows = ",len(imp))
print("Number of columns = ",len(imp.columns))
# Out:
# Number of rows =  4898
# Number of columns =  12

# %% [markdown]
# Total Number of rows are  and Total Number of columns are

# %% [markdown]
# ## 4.Find out the columns, data types, and presence of null values or missing values in the data set Univariate Analysis

# %%
#Finding out columns 

imp.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
#Finding out datatypes

imp.dtypes.to_frame(name='dtypes').T
# Out:
#        fixed acidity volatile acidity citric acid residual sugar chlorides  \
# dtypes       float64          float64     float64        float64   float64
#
#        free sulfur dioxide total sulfur dioxide  density       pH sulphates  \
# dtypes             float64              float64  float64  float64   float64
#
#         alcohol quality
# dtypes  float64   int64

# %%
#Finding out datatype

imp.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
imp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
#finding out null or not null values

imp.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 4893          False             False        False           False      False
# 4894          False             False        False           False      False
# 4895          False             False        False           False      False
# 4896          False             False        False           False      False
# 4897          False             False        False           False      False
#
#       free sulfur dioxide  total sulfur dioxide  density     pH  sulphates  \
# 0                   False                 False    False  False      False
# 1                   False                 False    False  False      False
# 2                   False                 False    False  False      False
# 3                   False                 False    False  False      False
# 4                   False                 False    False  False      False
# ...                   ...                   ...      ...    ...        ...
# 4893                False                 False    False  False      False
# 4894                False                 False    False  False      False
# 4895                False                 False    False  False      False
# 4896                False                 False    False  False      False
# 4897                False                 False    False  False      False
#
#       alcohol  quality
# 0       False    False
# 1       False    False
# 2       False    False
# 3       False    False
# 4       False    False
# ...       ...      ...
# 4893    False    False
# 4894    False    False
# 4895    False    False
# 4896    False    False
# 4897    False    False
#
# [4898 rows x 12 columns]

# %%
imp.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ## 5. Find out missing values graphically

# %%
nx_hist = imp.isnull().sum()

plt.figure(figsize=[10,5])

#nx = plt.hist(x=nx_hist)

plt.grid(axis='y', alpha=0.75)

plt.xlabel('Value',fontsize=15)

plt.xticks(fontsize=15)

plt.yticks(fontsize=15)

plt.title('Tip Histogram - Bins 20',fontsize=15)

nx_hist.plot()
# Out:
# <AxesSubplot:title={'center':'Tip Histogram - Bins 20'}, xlabel='Value'>

# %%
#We can do it as also:--

hist_1 = imp.isnull().sum()
hist_1.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
#  ## 6.Find out the number of rows, mean, std deviation, min, Q1, Q2, Q3, max values for each variable. Document your         observations to check if the outliers are present in the data set

# %%
imp.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
round(imp.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count         4898.0            4898.0       4898.0          4898.0
# mean             7.0               0.0          0.0             6.0
# std              1.0               0.0          0.0             5.0
# min              4.0               0.0          0.0             1.0
# 25%              6.0               0.0          0.0             2.0
# 50%              7.0               0.0          0.0             5.0
# 75%              7.0               0.0          0.0            10.0
# max             14.0               1.0          2.0            66.0
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density      pH  \
# count     4898.0               4898.0                4898.0   4898.0  4898.0
# mean         0.0                 35.0                 138.0      1.0     3.0
# std          0.0                 17.0                  42.0      0.0     0.0
# min          0.0                  2.0                   9.0      1.0     3.0
# 25%          0.0                 23.0                 108.0      1.0     3.0
# 50%          0.0                 34.0                 134.0      1.0     3.0
# 75%          0.0                 46.0                 167.0      1.0     3.0
# max          0.0                289.0                 440.0      1.0     4.0
#
#        sulphates  alcohol  quality
# count     4898.0   4898.0   4898.0
# mean         0.0     11.0      6.0
# std          0.0      1.0      1.0
# min          0.0      8.0      3.0
# 25%          0.0     10.0      5.0
# 50%          0.0     10.0      6.0
# 75%          1.0     11.0      6.0
# max          1.0     14.0      9.0

# %%
f_d = imp.describe()

# %%
fa = f_d['fixed acidity']
print(fa)

print()

fa_q1 = fa.iloc[4]
fa_q3 = fa.iloc[6]

print("Fixed Acidity Q1 : ",fa_q1)
print("Fixed Acidity Q3 : ",fa_q3)

print()

fa_iqr = fa_q3 - fa_q1
print("Fixed Acidity IQR : ",fa_iqr)

print()

fa_out_l = fa_q1 - (1.5 * fa_iqr)
print("Fixed Acidity Lower Outliers : ",fa_out_l)

fa_out_u = fa_q3 + (1.5 * fa_iqr)
print("Fixed Acidity Upper Outliers : ",fa_out_u)

for i in fa:
    if(i<fa_out_l or i>fa_out_u):
        print("\nOutliers Of Fixed Acidity",i)
# Out:
# count    4898.000000
# mean        6.854788
# std         0.843868
# min         3.800000
# 25%         6.300000
# 50%         6.800000
# 75%         7.300000
# max        14.200000
# Name: fixed acidity, dtype: float64
#
# Fixed Acidity Q1 :  6.3
# Fixed Acidity Q3 :  7.3
#
# Fixed Acidity IQR :  1.0
#
# Fixed Acidity Lower Outliers :  4.8
# Fixed Acidity Upper Outliers :  8.8
#
# Outliers Of Fixed Acidity 4898.0
#
# Outliers Of Fixed Acidity 0.8438682276875188
#
# Outliers Of Fixed Acidity 3.8
#
# Outliers Of Fixed Acidity 14.2

# %%
va = f_d['volatile acidity']
print(va)

print()

va_q1 = va.iloc[4]
va_q3 = va.iloc[6]

print("Volatile Acidity Q1 : ",fa_q1)
print("Volatile Acidity Q3 : ",fa_q3)

print()

va_iqr = va_q3 - va_q1
print("Volatile Acidity IQR : ",fa_iqr)

print()

va_out_l = va_q1 - (1.5 *va_iqr)
print("Volatile Acidity Lower Outliers : ",va_out_l)

va_out_u = va_q3 + (1.5 * va_iqr)
print("Volatile Acidity Upper Outliers : ",va_out_u)

for i in va:
    if(i<va_out_l or i>va_out_u):
        print("\nOutliers Of Volatile Acidity",i)
# Out:
# count    4898.000000
# mean        0.278241
# std         0.100795
# min         0.080000
# 25%         0.210000
# 50%         0.260000
# 75%         0.320000
# max         1.100000
# Name: volatile acidity, dtype: float64
#
# Volatile Acidity Q1 :  6.3
# Volatile Acidity Q3 :  7.3
#
# Volatile Acidity IQR :  1.0
#
# Volatile Acidity Lower Outliers :  0.04499999999999996
# Volatile Acidity Upper Outliers :  0.48500000000000004
#
# Outliers Of Volatile Acidity 4898.0
#
# Outliers Of Volatile Acidity 1.1

# %%
ca = f_d['citric acid']
print(ca)

print()

ca_q1 = ca.iloc[4]
ca_q3 = ca.iloc[6]

print("Citric Acid Q1 : ",ca_q1)
print("Citric Acid Q3 : ",ca_q3)

print()

ca_iqr = ca_q3 - ca_q1
print("Citric Acid IQR : ",ca_iqr)

print()

ca_out_l = ca_q1 - (1.5 * ca_iqr)
print("Citric Acid Lower Outliers : ",ca_out_l)

ca_out_u = ca_q3 + (1.5 * ca_iqr)
print("Citric Acid Upper Outliers : ",ca_out_u)

for i in ca:
    if(i<ca_out_l or i>ca_out_u):
        print("\nOutliers Of Citric Acid",i)
# Out:
# count    4898.000000
# mean        0.334192
# std         0.121020
# min         0.000000
# 25%         0.270000
# 50%         0.320000
# 75%         0.390000
# max         1.660000
# Name: citric acid, dtype: float64
#
# Citric Acid Q1 :  0.27
# Citric Acid Q3 :  0.39
#
# Citric Acid IQR :  0.12
#
# Citric Acid Lower Outliers :  0.09000000000000002
# Citric Acid Upper Outliers :  0.5700000000000001
#
# Outliers Of Citric Acid 4898.0
#
# Outliers Of Citric Acid 0.0
#
# Outliers Of Citric Acid 1.66

# %%
rs = f_d['residual sugar']
print(rs)

print()

rs_q1 = rs.iloc[4]
rs_q3 = rs.iloc[6]

print("Residual Sugar Q1 : ",rs_q1)
print("Residual Sugar Q3 : ",rs_q3)

print()

rs_iqr = rs_q3 - rs_q1
print("Residual Sugar IQR : ",rs_iqr)

print()

rs_out_l = rs_q1 - (1.5 * rs_iqr)
print("Residual Sugar Lower Outliers : ",rs_out_l)

rs_out_u = rs_q3 + (1.5 * rs_iqr)
print("Residual Sugar Upper Outliers : ",rs_out_u)

for i in rs:
    if(i<rs_out_l or i>rs_out_u):
        print("\nOutliers Of Residual Sugar",i)
# Out:
# count    4898.000000
# mean        6.391415
# std         5.072058
# min         0.600000
# 25%         1.700000
# 50%         5.200000
# 75%         9.900000
# max        65.800000
# Name: residual sugar, dtype: float64
#
# Residual Sugar Q1 :  1.7
# Residual Sugar Q3 :  9.9
#
# Residual Sugar IQR :  8.200000000000001
#
# Residual Sugar Lower Outliers :  -10.600000000000001
# Residual Sugar Upper Outliers :  22.200000000000003
#
# Outliers Of Residual Sugar 4898.0
#
# Outliers Of Residual Sugar 65.8

# %%
c = f_d['chlorides']
print(c)

print()

c_q1 = c.iloc[4]
c_q3 = c.iloc[6]

print("Chlorides Q1 : ",c_q1)
print("Chlorides Q3 : ",c_q3)

print()

c_iqr = c_q3 - c_q1
print("Chlorides IQR : ",rs_iqr)

print()

c_out_l = c_q1 - (1.5 * c_iqr)
print("Chlorides Lower Outliers : ",c_out_l)

c_out_u = c_q3 + (1.5 * c_iqr)
print("Chlorides Upper Outliers : ",c_out_u)

for i in c:
    if(i<c_out_l or i>c_out_u):
        print("\nOutliers Of Chlorides",i)
# Out:
# count    4898.000000
# mean        0.045772
# std         0.021848
# min         0.009000
# 25%         0.036000
# 50%         0.043000
# 75%         0.050000
# max         0.346000
# Name: chlorides, dtype: float64
#
# Chlorides Q1 :  0.036000000000000004
# Chlorides Q3 :  0.05
#
# Chlorides IQR :  8.200000000000001
#
# Chlorides Lower Outliers :  0.015000000000000006
# Chlorides Upper Outliers :  0.07100000000000001
#
# Outliers Of Chlorides 4898.0
#
# Outliers Of Chlorides 0.009000000000000001
#
# Outliers Of Chlorides 0.34600000000000003

# %%
fsd = f_d['free sulfur dioxide']
print(fsd)

print()

fsd_q1 = fsd.iloc[4]
fsd_q3 = fsd.iloc[6]

print("Free Sulfur Dioxide Q1 : ",fsd_q1)
print("Free Sulfur Dioxide Q3 : ",fsd_q3)

print()

fsd_iqr = fsd_q3 - fsd_q1
print("Free Sulfur Dioxide IQR : ",fsd_iqr)

print()

fsd_out_l = fsd_q1 - (1.5 * fsd_iqr)
print("Free Sulfur Dioxide Lower Outliers : ",fsd_out_l)

fsd_out_u = fsd_q3 + (1.5 * fsd_iqr)
print("Free Sulfur Dioxide Upper Outliers : ",fsd_out_u)

for i in fsd:
    if(i<fsd_out_l or i>fsd_out_u):
        print("\nOutliers Of Free Sulfur Dioxide",i)
# Out:
# count    4898.000000
# mean       35.308085
# std        17.007137
# min         2.000000
# 25%        23.000000
# 50%        34.000000
# 75%        46.000000
# max       289.000000
# Name: free sulfur dioxide, dtype: float64
#
# Free Sulfur Dioxide Q1 :  23.0
# Free Sulfur Dioxide Q3 :  46.0
#
# Free Sulfur Dioxide IQR :  23.0
#
# Free Sulfur Dioxide Lower Outliers :  -11.5
# Free Sulfur Dioxide Upper Outliers :  80.5
#
# Outliers Of Free Sulfur Dioxide 4898.0
#
# Outliers Of Free Sulfur Dioxide 289.0

# %%
tsd = f_d['total sulfur dioxide']
print(tsd)

print()

tsd_q1 = tsd.iloc[4]
tsd_q3 = tsd.iloc[6]

print("Total Sulfur Dioxide Q1 : ",tsd_q1)
print("Total Sulfur Dioxide Q3 : ",tsd_q3)

print()

tsd_iqr = tsd_q3 - tsd_q1
print("Total Sulfur Dioxide IQR : ",tsd_iqr)

print()

tsd_out_l = tsd_q1 - (1.5 * tsd_iqr)
print("Total Sulfur Dioxide Lower Outliers : ",tsd_out_l)

tsd_out_u = tsd_q3 + (1.5 * tsd_iqr)
print("Total Sulfur Dioxide Upper Outliers : ",tsd_out_u)

for i in tsd:
    if(i<tsd_out_l or i>tsd_out_u):
        print("\nOutliers Of Total Sulfur Dioxide",i)
# Out:
# count    4898.000000
# mean      138.360657
# std        42.498065
# min         9.000000
# 25%       108.000000
# 50%       134.000000
# 75%       167.000000
# max       440.000000
# Name: total sulfur dioxide, dtype: float64
#
# Total Sulfur Dioxide Q1 :  108.0
# Total Sulfur Dioxide Q3 :  167.0
#
# Total Sulfur Dioxide IQR :  59.0
#
# Total Sulfur Dioxide Lower Outliers :  19.5
# Total Sulfur Dioxide Upper Outliers :  255.5
#
# Outliers Of Total Sulfur Dioxide 4898.0
#
# Outliers Of Total Sulfur Dioxide 9.0
#
# Outliers Of Total Sulfur Dioxide 440.0

# %%
d = f_d['density']
print(d)

print()

d_q1 = d.iloc[4]
d_q3 = d.iloc[6]

print("Density Q1 : ",d_q1)
print("Density Q3 : ",d_q3)

print()

d_iqr = d_q3 - d_q1
print("Density IQR : ",d_iqr)

print()

d_out_l = d_q1 - (1.5 * d_iqr)
print("Density Lower Outliers : ",d_out_l)

d_out_u = d_q3 + (1.5 * d_iqr)
print("Density Upper Outliers : ",d_out_u)

for i in d:
    if(i<d_out_l or i>d_out_u):
        print("\nOutliers Of Density",i)
# Out:
# count    4898.000000
# mean        0.994027
# std         0.002991
# min         0.987110
# 25%         0.991723
# 50%         0.993740
# 75%         0.996100
# max         1.038980
# Name: density, dtype: float64
#
# Density Q1 :  0.9917225000000001
# Density Q3 :  0.9961
#
# Density IQR :  0.004377499999999923
#
# Density Lower Outliers :  0.9851562500000002
# Density Upper Outliers :  1.0026662499999999
#
# Outliers Of Density 4898.0
#
# Outliers Of Density 0.0029909069169369393
#
# Outliers Of Density 1.03898

# %%
ph = f_d['pH']
print(ph)

print()

ph_q1 = ph.iloc[4]
ph_q3 = ph.iloc[6]

print("PH Q1 : ",ph_q1)
print("PH Q3 : ",ph_q3)

print()

ph_iqr = ph_q3 - ph_q1
print("PH IQR : ",ph_iqr)

print()

ph_out_l = ph_q1 - (1.5 * ph_iqr)
print("PH Lower Outliers : ",ph_out_l)

ph_out_u = ph_q3 + (1.5 * ph_iqr)
print("PH Upper Outliers : ",d_out_u)

for i in ph:
    if(i<ph_out_l or i>ph_out_u):
        print("\nOutliers Of PH",i)
# Out:
# count    4898.000000
# mean        3.188267
# std         0.151001
# min         2.720000
# 25%         3.090000
# 50%         3.180000
# 75%         3.280000
# max         3.820000
# Name: pH, dtype: float64
#
# PH Q1 :  3.09
# PH Q3 :  3.28
#
# PH IQR :  0.18999999999999995
#
# PH Lower Outliers :  2.8049999999999997
# PH Upper Outliers :  1.0026662499999999
#
# Outliers Of PH 4898.0
#
# Outliers Of PH 0.1510005996150667
#
# Outliers Of PH 2.72
#
# Outliers Of PH 3.82

# %%
s = f_d['sulphates']
print(s)

print()

s_q1 = s.iloc[4]
s_q3 = s.iloc[6]

print("Sulphates Q1 : ",s_q1)
print("Sulphates Q3 : ",s_q3)

print()

s_iqr = s_q3 - s_q1
print("Sulphates IQR : ",s_iqr)

print()

s_out_l = s_q1 - (1.5 * s_iqr)
print("Sulphates Lower Outliers : ",s_out_l)

s_out_u = s_q3 + (1.5 * s_iqr)
print("Sulphates Upper Outliers : ",s_out_u)

for i in s:
    if(i<s_out_l or i>s_out_u):
        print("\nOutliers Of Sulphates",i)
# Out:
# count    4898.000000
# mean        0.489847
# std         0.114126
# min         0.220000
# 25%         0.410000
# 50%         0.470000
# 75%         0.550000
# max         1.080000
# Name: sulphates, dtype: float64
#
# Sulphates Q1 :  0.41
# Sulphates Q3 :  0.55
#
# Sulphates IQR :  0.14000000000000007
#
# Sulphates Lower Outliers :  0.19999999999999987
# Sulphates Upper Outliers :  0.7600000000000001
#
# Outliers Of Sulphates 4898.0
#
# Outliers Of Sulphates 0.11412583394883138
#
# Outliers Of Sulphates 1.08

# %%
a = f_d['alcohol']
print(a)

print()

a_q1 = a.iloc[4]
a_q3 = a.iloc[6]

print("Alcohol Q1 : ",a_q1)
print("Alcohol Q3 : ",a_q3)

print()

a_iqr = a_q3 - a_q1
print("Alcohol IQR : ",a_iqr)

print()

a_out_l = a_q1 - (1.5 * a_iqr)
print("Alcohol Lower Outliers : ",a_out_l)

a_out_u = a_q3 + (1.5 * a_iqr)
print("Alcohol Upper Outliers : ",a_out_u)

for i in a:
    if(i<a_out_l or i>a_out_u):
        print("\nOutliers Of Alcohol",i)
# Out:
# count    4898.000000
# mean       10.514267
# std         1.230621
# min         8.000000
# 25%         9.500000
# 50%        10.400000
# 75%        11.400000
# max        14.200000
# Name: alcohol, dtype: float64
#
# Alcohol Q1 :  9.5
# Alcohol Q3 :  11.4
#
# Alcohol IQR :  1.9000000000000004
#
# Alcohol Lower Outliers :  6.6499999999999995
# Alcohol Upper Outliers :  14.25
#
# Outliers Of Alcohol 4898.0
#
# Outliers Of Alcohol 1.2306205677573183

# %%
q = f_d['quality']
print(q)

print()

q_q1 = q.iloc[4]
q_q3 = q.iloc[6]

print("Quality Q1 : ",q_q1)
print("Quality Q3 : ",q_q3)

print()

q_iqr = q_q3 - q_q1
print("Quality IQR : ",q_iqr)

print()

q_out_l = q_q1 - (1.5 * q_iqr)
print("Quality Lower Outliers : ",q_out_l)

q_out_u = q_q3 + (1.5 * q_iqr)
print("Quality Upper Outliers : ",q_out_u)

for i in q:
    if(i<q_out_l or i>q_out_u):
        print("\nOutliers Of Quality",i)
# Out:
# count    4898.000000
# mean        5.877909
# std         0.885639
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         9.000000
# Name: quality, dtype: float64
#
# Quality Q1 :  5.0
# Quality Q3 :  6.0
#
# Quality IQR :  1.0
#
# Quality Lower Outliers :  3.5
# Quality Upper Outliers :  7.5
#
# Outliers Of Quality 4898.0
#
# Outliers Of Quality 0.8856385749678454
#
# Outliers Of Quality 3.0
#
# Outliers Of Quality 9.0

# %% [markdown]
# ## 7. Draw the histogram, kernel density estimate (kde) to check the distribution and skewness for each variable. Document your observation

# %% [markdown]
# ## Histogram

# %% [markdown]
# ## Fixed Acidity

# %%
plt.hist(imp['fixed acidity'],bins=10)
# Out:
# (array([2.300e+01, 4.480e+02, 2.405e+03, 1.548e+03, 3.850e+02, 8.200e+01,
#         5.000e+00, 1.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 3.8 ,  4.84,  5.88,  6.92,  7.96,  9.  , 10.04, 11.08, 12.12,
#         13.16, 14.2 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Volatile Acidity

# %%
plt.hist(imp['volatile acidity'],bins=10)
# Out:
# (array([7.300e+02, 2.265e+03, 1.316e+03, 4.010e+02, 1.070e+02, 5.800e+01,
#         1.300e+01, 2.000e+00, 4.000e+00, 2.000e+00]),
#  array([0.08 , 0.182, 0.284, 0.386, 0.488, 0.59 , 0.692, 0.794, 0.896,
#         0.998, 1.1  ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Citric Acid

# %%
plt.hist(imp['citric acid'],bins=10)
# Out:
# (array([2.190e+02, 2.651e+03, 1.679e+03, 2.450e+02, 9.200e+01, 5.000e+00,
#         5.000e+00, 1.000e+00, 0.000e+00, 1.000e+00]),
#  array([0.   , 0.166, 0.332, 0.498, 0.664, 0.83 , 0.996, 1.162, 1.328,
#         1.494, 1.66 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Residual Sugar

# %%
plt.hist(imp['residual sugar'],bins=10)
# Out:
# (array([2.981e+03, 1.373e+03, 5.270e+02, 1.400e+01, 2.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 0.6 ,  7.12, 13.64, 20.16, 26.68, 33.2 , 39.72, 46.24, 52.76,
#         59.28, 65.8 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Chlorides

# %%
plt.hist(imp['chlorides'],bins=10)
# Out:
# (array([2.394e+03, 2.329e+03, 7.300e+01, 3.500e+01, 3.900e+01, 1.800e+01,
#         5.000e+00, 2.000e+00, 2.000e+00, 1.000e+00]),
#  array([0.009 , 0.0427, 0.0764, 0.1101, 0.1438, 0.1775, 0.2112, 0.2449,
#         0.2786, 0.3123, 0.346 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Free Sulfur Dioxide

# %%
plt.hist(imp['free sulfur dioxide'],bins=10)
# Out:
# (array([2.072e+03, 2.440e+03, 3.590e+02, 1.900e+01, 6.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([  2. ,  30.7,  59.4,  88.1, 116.8, 145.5, 174.2, 202.9, 231.6,
#         260.3, 289. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Total Sulfur Dioxide

# %%
plt.hist(imp['total sulfur dioxide'],bins=10)
# Out:
# (array([5.200e+01, 6.820e+02, 1.884e+03, 1.470e+03, 6.840e+02, 1.160e+02,
#         6.000e+00, 2.000e+00, 1.000e+00, 1.000e+00]),
#  array([  9. ,  52.1,  95.2, 138.3, 181.4, 224.5, 267.6, 310.7, 353.8,
#         396.9, 440. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Density

# %%
plt.hist(imp['density'],bins=20)
# Out:
# (array([2.680e+02, 1.310e+03, 1.456e+03, 1.106e+03, 6.820e+02, 7.100e+01,
#         2.000e+00, 0.000e+00, 2.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([0.98711  , 0.9897035, 0.992297 , 0.9948905, 0.997484 , 1.0000775,
#         1.002671 , 1.0052645, 1.007858 , 1.0104515, 1.013045 , 1.0156385,
#         1.018232 , 1.0208255, 1.023419 , 1.0260125, 1.028606 , 1.0311995,
#         1.033793 , 1.0363865, 1.03898  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ## pH

# %%
plt.hist(imp['pH'],bins=20)
# Out:
# (array([  3.,   7.,  43., 119., 265., 366., 646., 685., 803., 604., 515.,
#         308., 235., 120.,  96.,  33.,  23.,  11.,   9.,   7.]),
#  array([2.72 , 2.775, 2.83 , 2.885, 2.94 , 2.995, 3.05 , 3.105, 3.16 ,
#         3.215, 3.27 , 3.325, 3.38 , 3.435, 3.49 , 3.545, 3.6  , 3.655,
#         3.71 , 3.765, 3.82 ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ## Sulphates

# %%
plt.hist(imp['sulphates'],bins=20)
# Out:
# (array([ 10.,  73., 232., 699., 649., 791., 890., 512., 367., 228., 173.,
#          90.,  76.,  58.,  11.,  15.,   9.,  11.,   2.,   2.]),
#  array([0.22 , 0.263, 0.306, 0.349, 0.392, 0.435, 0.478, 0.521, 0.564,
#         0.607, 0.65 , 0.693, 0.736, 0.779, 0.822, 0.865, 0.908, 0.951,
#         0.994, 1.037, 1.08 ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ## Alcohol

# %%
plt.hist(imp['alcohol'],bins=20)
# Out:
# (array([  2.,  35., 280., 528., 594., 375., 391., 370., 375., 390., 423.,
#         202., 222., 205., 214., 154.,  70.,  40.,  18.,  10.]),
#  array([ 8.  ,  8.31,  8.62,  8.93,  9.24,  9.55,  9.86, 10.17, 10.48,
#         10.79, 11.1 , 11.41, 11.72, 12.03, 12.34, 12.65, 12.96, 13.27,
#         13.58, 13.89, 14.2 ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ## Quality

# %%
plt.hist(imp['quality'],bins=7)
# Out:
# (array([  20.,  163., 1457., 2198.,  880.,  175.,    5.]),
#  array([3.        , 3.85714286, 4.71428571, 5.57142857, 6.42857143,
#         7.28571429, 8.14285714, 9.        ]),
#  <BarContainer object of 7 artists>)

# %% [markdown]
# ## Kernel Density Estimate

# %% [markdown]
# ## Fixed Acidity

# %%
imp['fixed acidity'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Volatile Acidity

# %%
imp['volatile acidity'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Citric Acid

# %%
imp['citric acid'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Residual Sugar

# %%
imp['residual sugar'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Chlorides

# %%
imp['chlorides'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Free Sulfur Dioxide

# %%
imp['free sulfur dioxide'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## total Sulfur Dioxide

# %%
imp['total sulfur dioxide'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Density

# %%
imp['density'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## pH

# %%
imp['pH'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Sulphates

# %%
imp['sulphates'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Alcohol

# %%
imp['alcohol'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Quality

# %%
imp['quality'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Skewness Of Each Variable

# %%
imp.skew()
# Out:
# fixed acidity           0.647751
# volatile acidity        1.576980
# citric acid             1.281920
# residual sugar          1.077094
# chlorides               5.023331
# free sulfur dioxide     1.406745
# total sulfur dioxide    0.390710
# density                 0.977773
# pH                      0.457783
# sulphates               0.977194
# alcohol                 0.487342
# quality                 0.155796
# dtype: float64

# %% [markdown]
# As we can see there is no negative value of any of the variable we can conclude that all of them are right skewed

# %% [markdown]
# ## Create a Fequency Distribution Table And Bar Chart For The Output Variable

# %%
sns.barplot(x=imp['fixed acidity'])
pd.crosstab(index=imp['fixed acidity'],columns='total')
# Out:
# col_0          total
# fixed acidity
# 3.8                1
# 3.9                1
# 4.2                2
# 4.4                3
# 4.5                1
# ...              ...
# 10.2               1
# 10.3               2
# 10.7               2
# 11.8               1
# 14.2               1
#
# [68 rows x 1 columns]

# %%
sns.barplot(x=imp['volatile acidity'])

pd.crosstab(index=imp['volatile acidity'],columns='total')
# Out:
# col_0             total
# volatile acidity
# 0.080                 4
# 0.085                 1
# 0.090                 1
# 0.100                 6
# 0.105                 6
# ...                 ...
# 0.910                 1
# 0.930                 1
# 0.965                 1
# 1.005                 1
# 1.100                 1
#
# [125 rows x 1 columns]

# %%
sns.barplot(x=imp['citric acid'])

pd.crosstab(index= imp['citric acid'],columns='total')
# Out:
# col_0        total
# citric acid
# 0.00            19
# 0.01             7
# 0.02             6
# 0.03             2
# 0.04            12
# ...            ...
# 0.91             2
# 0.99             1
# 1.00             5
# 1.23             1
# 1.66             1
#
# [87 rows x 1 columns]

# %%
sns.barplot(x=imp['residual sugar'])

pd.crosstab(index=imp['residual sugar'],columns='total')
# Out:
# col_0           total
# residual sugar
# 0.60                2
# 0.70                7
# 0.80               25
# 0.90               39
# 0.95                4
# ...               ...
# 22.60               1
# 23.50               1
# 26.05               2
# 31.60               2
# 65.80               1
#
# [310 rows x 1 columns]

# %%
sns.barplot(x=imp['chlorides'])

pd.crosstab(index=imp['chlorides'],columns='total')
# Out:
# col_0      total
# chlorides
# 0.009          1
# 0.012          1
# 0.013          1
# 0.014          4
# 0.015          4
# ...          ...
# 0.255          1
# 0.271          1
# 0.290          1
# 0.301          1
# 0.346          1
#
# [160 rows x 1 columns]

# %%
sns.barplot(x=imp['free sulfur dioxide'])

pd.crosstab(index=imp['free sulfur dioxide'],columns='total')
# Out:
# col_0                total
# free sulfur dioxide
# 2.0                      1
# 3.0                     10
# 4.0                     11
# 5.0                     25
# 6.0                     32
# ...                    ...
# 128.0                    1
# 131.0                    1
# 138.5                    1
# 146.5                    1
# 289.0                    1
#
# [132 rows x 1 columns]

# %%
sns.barplot(x=imp['density'])

pd.crosstab(index=imp['density'],columns='total')
# Out:
# col_0    total
# density
# 0.98711      1
# 0.98713      1
# 0.98722      1
# 0.98740      1
# 0.98742      2
# ...        ...
# 1.00240      1
# 1.00241      1
# 1.00295      2
# 1.01030      2
# 1.03898      1
#
# [890 rows x 1 columns]

# %%
sns.barplot(x=imp['pH'])

pd.crosstab(index=imp['pH'],columns='total')
# Out:
# col_0  total
# pH
# 2.72       1
# 2.74       1
# 2.77       1
# 2.79       3
# 2.80       3
# ...      ...
# 3.77       2
# 3.79       1
# 3.80       2
# 3.81       1
# 3.82       1
#
# [103 rows x 1 columns]

# %%
sns.barplot(x=imp['sulphates'])

pd.crosstab(index=imp['sulphates'],columns='total')
# Out:
# col_0      total
# sulphates
# 0.22           1
# 0.23           1
# 0.25           4
# 0.26           4
# 0.27          13
# ...          ...
# 0.99           1
# 1.00           1
# 1.01           1
# 1.06           1
# 1.08           1
#
# [79 rows x 1 columns]

# %%
sns.barplot(x=imp['alcohol'])

pd.crosstab(index=imp['alcohol'],columns='total')
# Out:
# col_0    total
# alcohol
# 8.00         2
# 8.40         3
# 8.50         9
# 8.60        23
# 8.70        78
# ...        ...
# 13.80        2
# 13.90        3
# 14.00        5
# 14.05        1
# 14.20        1
#
# [103 rows x 1 columns]

# %%
sns.barplot(x=imp['quality'])

pd.crosstab(index=imp['quality'],columns='total')
# Out:
# col_0    total
# quality
# 3           20
# 4          163
# 5         1457
# 6         2198
# 7          880
# 8          175
# 9            5

# %% [markdown]
# ## Draw box plot for each variable and identify the IQR and outliers

# %%
d = imp.describe()

# %% [markdown]
# ## Fixed Acidity

# %%
sns.set(style="whitegrid")
sns.boxplot(x=imp['fixed acidity'],data=imp)
# Out:
# <AxesSubplot:xlabel='fixed acidity'>

# %% [markdown]
# ## Volatile Acidity

# %%
sns.boxplot(x=imp['volatile acidity'],data=imp)
# Out:
# <AxesSubplot:xlabel='volatile acidity'>

# %% [markdown]
# ### Citric Acid

# %%
sns.boxplot(x=imp['citric acid'],data=imp)
# Out:
# <AxesSubplot:xlabel='citric acid'>

# %% [markdown]
# ### Residual Sugar

# %%
sns.boxplot(x=imp['residual sugar'],data=imp)
# Out:
# <AxesSubplot:xlabel='residual sugar'>

# %% [markdown]
# ### Chlorides

# %%
sns.boxplot(x=imp['chlorides'],data=imp)
# Out:
# <AxesSubplot:xlabel='chlorides'>

# %% [markdown]
# ### Free Sulfur Dioxide

# %%
sns.boxplot(x=imp['free sulfur dioxide'],data=imp)
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide'>

# %% [markdown]
# ### Total Sulfur Dioxide

# %%
sns.boxplot(x=imp['total sulfur dioxide'],data=imp)
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide'>

# %% [markdown]
# ## Density

# %%
sns.boxplot(x=imp['density'],data=imp)
# Out:
# <AxesSubplot:xlabel='density'>

# %% [markdown]
# ## pH

# %%
sns.boxplot(x=imp['pH'],data=imp)
# Out:
# <AxesSubplot:xlabel='pH'>

# %% [markdown]
# ## Sulphates

# %%
sns.boxplot(x=imp['sulphates'],data=imp)
# Out:
# <AxesSubplot:xlabel='sulphates'>

# %% [markdown]
# ## Alcohol

# %%
sns.boxplot(x=imp['alcohol'],data=imp)
# Out:
# <AxesSubplot:xlabel='alcohol'>

# %% [markdown]
# ## Quality

# %%
sns.boxplot(x=imp['quality'],data=imp)
# Out:
# <AxesSubplot:xlabel='quality'>

# %% [markdown]
# ## 3.Multivariate Analysis
#    # Draw the correlation matrix and identify the variables that are correlated to each other.¶

# %%
cr=imp.corr()
cr
cr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_96c52424_4478_11eb_a472_089798b6b00frow0_col0,#T_96c52424_4478_11eb_a472_089798b6b00frow1_col1,#T_96c52424_4478_11eb_a472_089798b6b00frow2_col2,#T_96c52424_4478_11eb_a472_089798b6b00frow3_col3,#T_96c52424_4478_11eb_a472_089798b6b00frow4_col4,#T_96c52424_4478_11eb_a472_089798b6b00frow5_col5,#T_96c52424_4478_11eb_a472_089798b6b00frow6_col6,#T_96c52424_4478_11eb_a472_089798b6b00frow7_col7,#T_96c52424_4478_11eb_a472_089798b6b00frow8_col8,#T_96c52424_4478_11eb_a472_089798b6b00frow9_col9,#T_96c52424_4478_11eb_a472_089798b6b00frow10_col10,#T_96c52424_4478_11eb_a472_089798b6b00frow11_col11{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow0_col1{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow0_col2{
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow0_col3,#T_96c52424_4478_11eb_a472_089798b6b00frow0_col6,#T_96c52424_4478_11eb_a472_089798b6b00frow1_col6,#T_96c52424_4478_11eb_a472_089798b6b00frow4_col3{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow0_col4,#T_96c52424_4478_11eb_a472_089798b6b00frow1_col0{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow0_col5,#T_96c52424_4478_11eb_a472_089798b6b00frow3_col8,#T_96c52424_4478_11eb_a472_089798b6b00frow3_col11{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow0_col7,#T_96c52424_4478_11eb_a472_089798b6b00frow3_col6,#T_96c52424_4478_11eb_a472_089798b6b00frow6_col3{
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow0_col8,#T_96c52424_4478_11eb_a472_089798b6b00frow1_col9,#T_96c52424_4478_11eb_a472_089798b6b00frow7_col10,#T_96c52424_4478_11eb_a472_089798b6b00frow7_col11,#T_96c52424_4478_11eb_a472_089798b6b00frow8_col0,#T_96c52424_4478_11eb_a472_089798b6b00frow8_col2,#T_96c52424_4478_11eb_a472_089798b6b00frow10_col3,#T_96c52424_4478_11eb_a472_089798b6b00frow10_col4,#T_96c52424_4478_11eb_a472_089798b6b00frow10_col5,#T_96c52424_4478_11eb_a472_089798b6b00frow10_col6,#T_96c52424_4478_11eb_a472_089798b6b00frow10_col7,#T_96c52424_4478_11eb_a472_089798b6b00frow11_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow0_col9,#T_96c52424_4478_11eb_a472_089798b6b00frow10_col9{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow0_col10,#T_96c52424_4478_11eb_a472_089798b6b00frow11_col8{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow0_col11{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow1_col2{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow1_col3{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow1_col4{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow1_col5{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow1_col7,#T_96c52424_4478_11eb_a472_089798b6b00frow7_col4{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow1_col8,#T_96c52424_4478_11eb_a472_089798b6b00frow2_col5,#T_96c52424_4478_11eb_a472_089798b6b00frow9_col4,#T_96c52424_4478_11eb_a472_089798b6b00frow9_col11{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow1_col10{
#             background-color:  #d6dce4;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow1_col11,#T_96c52424_4478_11eb_a472_089798b6b00frow11_col9{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow2_col0{
#             background-color:  #dddcdc;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow2_col1{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow2_col3{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow2_col4{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow2_col6{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow2_col7{
#             background-color:  #e2dad5;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow2_col8,#T_96c52424_4478_11eb_a472_089798b6b00frow3_col10,#T_96c52424_4478_11eb_a472_089798b6b00frow6_col10,#T_96c52424_4478_11eb_a472_089798b6b00frow7_col1,#T_96c52424_4478_11eb_a472_089798b6b00frow8_col9{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow2_col9{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow2_col10{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow2_col11{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow3_col0,#T_96c52424_4478_11eb_a472_089798b6b00frow6_col0{
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow3_col1{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow3_col2,#T_96c52424_4478_11eb_a472_089798b6b00frow4_col1,#T_96c52424_4478_11eb_a472_089798b6b00frow5_col2,#T_96c52424_4478_11eb_a472_089798b6b00frow10_col1,#T_96c52424_4478_11eb_a472_089798b6b00frow11_col0{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow3_col4{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow3_col5{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow3_col7{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow3_col9{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow4_col0{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow4_col2,#T_96c52424_4478_11eb_a472_089798b6b00frow5_col11{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow4_col5{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow4_col6{
#             background-color:  #cedaeb;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow4_col7{
#             background-color:  #efcebd;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow4_col8,#T_96c52424_4478_11eb_a472_089798b6b00frow4_col10,#T_96c52424_4478_11eb_a472_089798b6b00frow6_col1{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_96c52424_4478_11eb_a472_089798b6b00frow4_col9{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_96c52424_4478_11eb_a472_089798b6b00fr

# %%
plt.figure(figsize=[20,10])

sns.heatmap(imp.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(imp)

# %%
sns.relplot(y='fixed acidity' ,x='density', col='quality', data=imp)

# %%
sns.relplot(y='volatile acidity' ,x='density', col='quality', data=imp)

# %%
sns.relplot(y='citric acid' ,x='density', col='quality', data=imp)

# %%
sns.relplot(y='residual sugar' ,x='density', col='quality', data=imp)

# %%
sns.relplot(y='chlorides' ,x='density', col='quality', data=imp)

# %%
sns.relplot(y='free sulfur dioxide' ,x='density', col='quality', data=imp)

# %%
sns.relplot(y='total sulfur dioxide' ,x='density', col='quality', data=imp)

# %%
sns.relplot(y='density' ,x='density', col='quality', data=imp)

# %%
sns.relplot(y='pH' ,x='density', col='quality', data=imp)

# %%
sns.relplot(y='sulphates' ,x='density', col='quality', data=imp)

# %%
sns.relplot(y='alcohol' ,x='density', col='quality', data=imp)

# %%
sns.relplot(y='quality' ,x='density', col='quality', data=imp)

# %% [markdown]
#                                                     Thanks

# %% [markdown]
#                                               Yash Kumar Sharma
